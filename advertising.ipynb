# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_csv (r'C:\Users\rashi\Downloads\DSData-master\DSData-master\Advertising.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.shape
# Out:
# (200, 5)

# %% [markdown]
# this dataset have 200 rows and 5 columns

# %%
data.drop(['Unnamed: 0'], inplace =True, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# there is no null value in the dataset

# %%
data.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data['sales'].unique()
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. ,  5.6,
#        15.5, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,  9.5, 12.8,
#        25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7,  8.5, 14.9, 23.2, 14.8,
#        11.4, 10.7, 22.6, 21.2, 20.2, 23.7,  5.5, 23.8, 18.4,  8.1, 24.2,
#        15.7, 14. , 13.4, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 12.3, 13.6, 21.7, 15.2, 16. , 16.7, 11.2,  7.3, 19.4,
#        22.2, 11.5, 16.9, 11.7, 17.2, 19.2, 19.8, 21.8, 14.1, 12.6, 12.2,
#         9.4,  6.6,  7. , 11.6, 19.7, 24.7,  1.6, 12.7,  5.7, 19.6, 10.8,
#        20.8, 10.9, 20.1, 10.3, 16.1, 15.6,  3.2, 15.3, 14.4, 13.3,  8. ,
#         8.4, 14.5,  7.6, 27. , 26.2, 17.6, 17.3,  6.7,  9.9,  5.9, 25.5])

# %%
data.sales.value_counts().sort_index()
# Out:
# 1.6     1
# 3.2     1
# 4.8     1
# 5.3     2
# 5.5     1
#        ..
# 24.7    1
# 25.4    3
# 25.5    1
# 26.2    1
# 27.0    1
# Name: sales, Length: 121, dtype: int64

# %%
data.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# this shows the correlation of the dataset

# %%
data.mean()             #mean
# Out:
# TV           147.0425
# radio         23.2640
# newspaper     30.5540
# sales         14.0225
# dtype: float64

# %%
data.median()               #median
# Out:
# TV           149.75
# radio         22.90
# newspaper     25.75
# sales         12.90
# dtype: float64

# %%
data.mode()        #mode
# Out:
#       TV  radio  newspaper  sales
# 0   17.2    4.1        8.7    9.7
# 1   76.4    5.7        9.3    NaN
# 2  109.8    NaN       25.6    NaN
# 3  177.0    NaN        NaN    NaN
# 4  184.9    NaN        NaN    NaN
# 5  197.6    NaN        NaN    NaN
# 6  199.8    NaN        NaN    NaN
# 7  222.4    NaN        NaN    NaN
# 8  237.4    NaN        NaN    NaN
# 9  240.1    NaN        NaN    NaN

# %%
data.nunique()
# Out:
# TV           190
# radio        167
# newspaper    172
# sales        121
# dtype: int64

# %%
data.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
data.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %% [markdown]
# there is one integer type column and four float type columns

# %% [markdown]
# # eda

# %%
sns.countplot(x='sales', data=data)         #univariate analysis
# Out:
# <AxesSubplot:xlabel='sales', ylabel='count'>

# %% [markdown]
# this shows that data is imbalanced

# %%
sns.countplot(x='TV', data=data)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='count'>

# %% [markdown]
# this shows that data is somewhat balanced

# %%
sns.countplot(x='radio', data=data)
# Out:
# <AxesSubplot:xlabel='radio', ylabel='count'>

# %% [markdown]
# data is imbalanced

# %%
sns.countplot(x='newspaper', data=data)
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='count'>

# %%
bx = sns.boxplot(x="sales", y='newspaper', data = data)     #bivariate analysis
bx.set(xlabel='sales', ylabel='newspaper', title='Advertising')
# Out:
# [Text(0.5, 0, 'sales'),
#  Text(0, 0.5, 'newspaper'),
#  Text(0.5, 1.0, 'Advertising')]

# %%
sns.distplot(data['sales'])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# data is normally distributed

# %%
sns.distplot(data['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %% [markdown]
# data is not normally distributed

# %%
sns.distplot(data['radio'])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %% [markdown]
# data is not normally distributed

# %%
sns.distplot(data['newspaper'])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %% [markdown]
# data is normally distributed

# %%
sns.boxplot(data['sales'])
# Out:
# <AxesSubplot:xlabel='sales'>

# %% [markdown]
# there are no outliers

# %%
sns.boxplot(data['TV'])
# Out:
# <AxesSubplot:xlabel='TV'>

# %% [markdown]
# there are no outliers

# %%
sns.boxplot(data['radio'])
# Out:
# <AxesSubplot:xlabel='radio'>

# %% [markdown]
# there are no outliers

# %%
sns.boxplot(data['newspaper'])
# Out:
# <AxesSubplot:xlabel='newspaper'>

# %% [markdown]
# there are outliers in this column

# %% [markdown]
# # bivariate analysis

# %%
plt.figure(figsize=[10,6])
plt.title('comparision between sales and tv')
sns.scatterplot(data['sales'],data['TV']);

# %%
plt.figure(figsize=[10,6])
plt.title('comparision between sales and tv')
sns.scatterplot(data['sales'],data['radio']);

# %%
plt.figure(figsize=[10,6])
plt.title('comparision between sales and tv')
sns.scatterplot(data['sales'],data['newspaper']);

# %%
sns.pairplot(data,hue='sales')             #multivariate analysis

# %%
cor=data.corr               #multivariate analysis

# %%
cor
# Out:
# <bound method DataFrame.corr of         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(),annot=True,cbar_kws={'orientation':'horizontal'},annot_kws={'size':15})
# Out:
# <AxesSubplot:>

# %% [markdown]
# all the values in this heatmap lies between 0.15 to -0.15

# %% [markdown]
# # outliers removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(data))
new_data=data[(z<3).all(axis=1)]

# %%
new_data.shape
# Out:
# (198, 4)

# %%
data.shape
# Out:
# (200, 4)

# %%
(2/200)*100
# Out:
# 1.0

# %%
new_data.skew()
# Out:
# TV          -0.082332
# radio        0.114842
# newspaper    0.650112
# sales        0.407130
# dtype: float64

# %% [markdown]
# as some values do not lies between 0.5 - -0.5 , so the data is not skewed

# %% [markdown]
# # model building

# %%
new_data.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
y=new_data['sales']

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
x=new_data.drop(['sales'], axis=1)

# %%
x.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
from sklearn import linear_model
import statsmodels.api as sm

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  2.952308567118184
# Coefficients:
#  [ 0.04569034  0.18855047 -0.00117766]

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
print(regr.fit)
# Out:
# <bound method LinearRegression.fit of LinearRegression()>
