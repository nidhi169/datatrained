# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\rashi\Downloads\DSData-master\DSData-master\happiness_score_dataset.csv')

# %%
df.head(n=159)
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# there are 158 rows and 12 columns in this dataset

# %%
df.shape
# Out:
# (158, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# there are 9 float datatype, 1 interger datatype and 2 object datatype

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
NULLS=df[df.isnull().any(axis=1)]
NULLS.head()
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.sort_values(by="Happiness Rank", ascending=True).head(158)
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.sort_values(by="Happiness Rank", ascending=False).head(158)
# Out:
#          Country                           Region  Happiness Rank  \
# 157         Togo               Sub-Saharan Africa             158
# 156      Burundi               Sub-Saharan Africa             157
# 155        Syria  Middle East and Northern Africa             156
# 154        Benin               Sub-Saharan Africa             155
# 153       Rwanda               Sub-Saharan Africa             154
# ..           ...                              ...             ...
# 4         Canada                    North America               5
# 3         Norway                   Western Europe               4
# 2        Denmark                   Western Europe               3
# 1        Iceland                   Western Europe               2
# 0    Switzerland                   Western Europe               1
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 157            2.839         0.06727                   0.20868  0.13995
# ...

# %% [markdown]
# # indexing and grouping

# %%
df_Region = df.groupby('Region')
df_Region['Happiness Score'].describe().sort_values(by="mean",ascending=True).head(158)
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Sub-Saharan Africa                40.0  4.202800  0.609557  2.839  3.75600
# Southern Asia                      7.0  4.580857  0.570526  3.575  4.39250
# Southeastern Asia                  9.0  5.317444  0.950020  3.819  4.87600
# Central and Eastern Europe        29.0  5.332931  0.570446  4.218  4.95900
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
#
#                                    50%      75%    max
# Region
# Sub-Saharan Africa               4.272  4.58075  5.477
# ...

# %% [markdown]
# there are 40 countries of sub-saharan africa , 7 countries of southern asia, 9 countries of southeastern asia, 29 countries of central and eastern europe, 20 countries of middle east and northern africa, 6 countries of eastern asia, 22 countries of latin america and caribbean, 21 countries of western europe,2 countries of north america and 2 countries of australia & new zealand

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# mean value of happiness score is 5

# %%
df_ssa = df[df['Region'] == 'Sub-Saharan Africa']
df_sa = df[df['Region'] == 'Southern Asia']
df_sea = df[df['Region'] == 'Southeastern Asia']
df_cee = df[df['Region'] == 'Central and Eastern Europe']
df_mena = df[df['Region'] == 'Middle East and Northern Africa']
df_ea = df[df['Region'] == 'Eastern Asia']
df_lac = df[df['Region'] == 'Latin America and Caribbean']
df_we = df[df['Region'] == 'Western Europe']
df_na = df[df['Region'] == 'North America']
df_anz = df[df['Region'] == 'Australia and New Zealand']

# %%
len(df_ssa[df_ssa['Happiness Score'] > 5])
# Out:
# 4

# %% [markdown]
# there are 4 countries in sub-sahara africa which have happiness score above 5

# %%
len(df_ssa[df_ssa['Happiness Score'] < 5])
# Out:
# 36

# %% [markdown]
# there are 36 countries in sub-sahara africa which have happiness score below 5

# %%
len(df_sa[df_sa['Happiness Score'] > 5])
# Out:
# 2

# %% [markdown]
# there are 2 countries in southern asia which have happiness score above 5 & 5 countries below 5

# %%
len(df_sea[df_sea['Happiness Score'] > 5])
# Out:
# 6

# %%
len(df_sea[df_sea['Happiness Score'] < 5])
# Out:
# 3

# %% [markdown]
# there are 6 countries in Southeastern Asia which have happiness score above 5 & 3 countries below 5

# %%
len(df_cee[df_cee['Happiness Score'] > 5])
# Out:
# 21

# %%
len(df_cee[df_cee['Happiness Score'] < 5])
# Out:
# 8

# %% [markdown]
# there are 21 countries in central and eastern europe which have happiness score above 5 & 8 countries below 5

# %%
len(df_mena[df_mena['Happiness Score'] > 5])
# Out:
# 12

# %%
len(df_mena[df_mena['Happiness Score'] < 5])
# Out:
# 8

# %% [markdown]
# there are 12 countries in middle east and northern africa which have happiness score above 5 & 8 countries below 5

# %%
len(df_ea[df_ea['Happiness Score'] > 5])
# Out:
# 5

# %%
len(df_ea[df_ea['Happiness Score'] < 5])
# Out:
# 1

# %% [markdown]
# there are 5 countries in eastern asia which have happiness score above 5 & 1 country below 5

# %%
len(df_lac[df_lac['Happiness Score'] > 5])
# Out:
# 19

# %%
len(df_lac[df_lac['Happiness Score'] < 5])
# Out:
# 3

# %% [markdown]
# there are 19 countries in latin america and caribbean which have happiness score above 5 & 3 countries below 5

# %%
len(df_we[df_we['Happiness Score'] > 5])
# Out:
# 20

# %%
len(df_we[df_we['Happiness Score'] < 5])
# Out:
# 1

# %% [markdown]
# there are 20 countries in western europe which have haappiness score above 5 & 1 country below 5

# %%
len(df_na[df_na['Happiness Score'] > 5])
# Out:
# 2

# %%
len(df_na[df_na['Happiness Score'] < 5])
# Out:
# 0

# %% [markdown]
# there are 2 countries in north america which have happiness score above 5 & 0 country below 5

# %%
len(df_anz[df_anz['Happiness Score'] > 5])
# Out:
# 2

# %%
len(df_anz[df_anz['Happiness Score'] < 5])
# Out:
# 0

# %% [markdown]
# there are 2 countries in australia and new zealand which have happiness score above 5 & 0 country below 5

# %%
Delta_ssa = df_ssa.max(axis=0)['Happiness Score'] - df_ssa.min(axis=0)['Happiness Score']
print(Delta_ssa)
# Out:
# 2.6380000000000003

# %%
Delta_sa = df_sa.max(axis=0)['Happiness Score'] - df_sa.min(axis=0)['Happiness Score']
print(Delta_sa)
# Out:
# 1.677999999999999

# %%
Delta_sea = df_sea.max(axis=0)['Happiness Score'] - df_sea.min(axis=0)['Happiness Score']
print(Delta_sea)
# Out:
# 2.978999999999999

# %%
Delta_cee = df_cee.max(axis=0)['Happiness Score'] - df_cee.min(axis=0)['Happiness Score']
print(Delta_cee)
# Out:
# 2.287

# %%
Delta_mena = df_mena.max(axis=0)['Happiness Score'] - df_mena.min(axis=0)['Happiness Score']
print(Delta_mena)
# Out:
# 4.271999999999999

# %%
Delta_ea = df_ea.max(axis=0)['Happiness Score'] - df_ea.min(axis=0)['Happiness Score']
print(Delta_ea)
# Out:
# 1.4239999999999995

# %%
Delta_lac = df_lac.max(axis=0)['Happiness Score'] - df_lac.min(axis=0)['Happiness Score']
print(Delta_lac)
# Out:
# 2.708

# %%
Delta_we = df_we.max(axis=0)['Happiness Score'] - df_we.min(axis=0)['Happiness Score']
print(Delta_we)
# Out:
# 2.7300000000000004

# %%
Delta_na = df_na.max(axis=0)['Happiness Score'] - df_na.min(axis=0)['Happiness Score']
print(Delta_na)
# Out:
# 0.3080000000000007

# %%
Delta_anz = df_anz.max(axis=0)['Happiness Score'] - df_anz.min(axis=0)['Happiness Score']
print(Delta_anz)
# Out:
# 0.002000000000000668

# %%
Deltas = {}

# %%
Deltas["sub_Sahara Africa"] = Delta_ssa
Deltas["Southern Asia"] = Delta_sa
Deltas["Southeastern Asia"] = Delta_sea
Deltas["Central and Eastern Europe"] = Delta_cee
Deltas["Middle East and Northern Africa"] = Delta_mena
Deltas["Eastern Asia"] = Delta_ea
Deltas["North America"] = Delta_na
Deltas["Latin America and Caribbean"] = Delta_lac
Deltas["Western Europe"] = Delta_we
Deltas["Australia and New Zealand"] = Delta_anz

# %%
print("The {} region seems to have the largest range of happiness scores".format(max(Deltas, key=Deltas.get)))
# Out:
# The Middle East and Northern Africa region seems to have the largest range of happiness scores

# %%
print("The {} region seems to have the smallest range of happiness scores".format(min(Deltas, key=Deltas.get)))
# Out:
# The Australia and New Zealand region seems to have the smallest range of happiness scores

# %% [markdown]
# # bar plot of happiness score

# %%
df['Happiness Score'].head(158).plot(xticks=np.arange(158), kind='barh', figsize= (158, 12))
plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 158 Countries')
# Out:
# Text(0.5, 1.0, 'Happiness Score of the top 158 Countries')

# %%
df[['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual' ]].head(158).plot(kind='barh',
                                                                xticks=np.arange(12), stacked=True, figsize= (158, 158))

plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 158 Countries')
plt.legend(bbox_to_anchor=(0.5, 1.0), loc=2, borderaxespad=0.)

# %% [markdown]
# # scatter plot

# %%
sns.pairplot(data=df, kind='reg', size = 5,
                  x_vars=['Happiness Score'],
                  y_vars=['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual' ])
# Out:
# C:\Users\rashi\anaconda3\New folder\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=df, size = 5, hue='Region',
                  x_vars=['Happiness Score'],
                  y_vars=['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual'])
# Out:
# C:\Users\rashi\anaconda3\New folder\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # correlation

# %%
df.corr(method="pearson", min_periods=5)["Happiness Score"].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %%
df.corr(method="pearson", min_periods=5)["Happiness Score"].abs().sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Happiness Rank                   0.992105
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                   0.177254
# Name: Happiness Score, dtype: float64

# %%
df.corr(method="pearson", min_periods=5)
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
corr = df.corr(method = "pearson")

f, ax = plt.subplots(figsize=(12, 12))

sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), 
            cmap=sns.diverging_palette(220, 12, as_cmap=True), square=True, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # matrices

# %%
df.shape
# Out:
# (158, 12)

# %%
Sub_Saharan_Africa = []
Southern_Asia = []
Southeastern_Asia = []
Central_and_Eastern_Europe = []
Middle_East_and_Northern_Africa = []
Eastern_Asia = []
Latin_America_and_Caribbean = []
Western_Europe = []
North_America = []
Australia_and_New_Zealand = []

# %%
for x in df['Region']:
    if x == 'Sub-Sahara Africa':
         Sub_Saharan_Africa.append(1)
    else: Sub_Saharan_Africa.append(0)

# %%
for x in df['Region']:
    if x == 'Southern Asia':
         Southern_Asia.append(1)
    else: Southern_Asia.append(0)

# %%
for x in df['Region']:
    if x == 'Southeastern Asia':
         Southeastern_Asia.append(1)
    else: Southeastern_Asia.append(0)

# %%
for x in df['Region']:
    if x == 'Central and Eastern Europe':
         Central_and_Eastern_Europe.append(1)
    else: Central_and_Eastern_Europe.append(0)

# %%
for x in df['Region']:
    if x == 'Middle East and Northern Africa':
         Middle_East_and_Northern_Africa.append(1)
    else: Middle_East_and_Northern_Africa.append(0)

# %%
for x in df['Region']:
    if x == 'Eastern Asia':
         Eastern_Asia.append(1)
    else: Eastern_Asia.append(0)

# %%
for x in df['Region']:
    if x == 'Latin America and Caribbean':
         Latin_America_and_Caribbean.append(1)
    else: Latin_America_and_Caribbean.append(0)

# %%
for x in df['Region']:
    if x == 'Western Europe':
         Western_Europe.append(1)
    else: Western_Europe.append(0)

# %%
for x in df['Region']:
    if x == 'North America':
         North_America.append(1)
    else: North_America.append(0)

# %%
for x in df['Region']:
    if x == 'Australia and New Zealand':
         Australia_and_New_Zealand.append(1)
    else: Australia_and_New_Zealand.append(0)

# %%
Matrix = pd.DataFrame(index=df.index)

# %%
Matrix['Sub Saharan Africa'] = Sub_Saharan_Africa
Matrix['Southern Asia'] = Southern_Asia
Matrix['Southeastern Asia'] = Southeastern_Asia
Matrix['Central_and_Eastern_Europe'] = Central_and_Eastern_Europe
Matrix['Middle East and Northern Africa'] = Middle_East_and_Northern_Africa
Matrix['Eastern Asia'] = Eastern_Asia
Matrix['Western Europe'] = Western_Europe
Matrix['Latin America and Caribbean'] = Latin_America_and_Caribbean
Matrix['North America'] = North_America
Matrix['Australia and New Zealand'] = Australia_and_New_Zealand

# %%
Matrix.head(158)
# Out:
#      Sub Saharan Africa  Southern Asia  Southeastern Asia  \
# 0                     0              0                  0
# 1                     0              0                  0
# 2                     0              0                  0
# 3                     0              0                  0
# 4                     0              0                  0
# ..                  ...            ...                ...
# 153                   0              0                  0
# 154                   0              0                  0
# 155                   0              0                  0
# 156                   0              0                  0
# 157                   0              0                  0
#
#      Central_and_Eastern_Europe  Middle East and Northern Africa  \
# 0                             0                                0
# 1                             0                                0
# 2                             0                                0
# ...

# %%
array_Matrix =df

# %%
array_Matrix
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...
